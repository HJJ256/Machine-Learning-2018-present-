# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=[5,5,10,10,15,15,17,17,20,20,30,30,30,30,30,30,40,40,40,40,40,40,5,5,10,10,15,15,17,17,20,20,5,5,5,5,5,5,5,10,10,10,10,10]
y1=[5,10,5,10,5,10,5,10,5,10,5,10,15,20,25,30,35,40,15,20,25,30,35,40,35,40,35,40,35,40,35,40,35,40,15,20,25,30,35,15,20,25,30,35]

# %%
len(x1)
# Out:
# 44

# %%
len(y1)
# Out:
# 44

# %%
#plt.scatter(x1,y1)

# %%
x2=[15,20,25,15,20,25,15,20,25]
y2=[15,15,15,20,20,20,25,25,25]

# %%
#plt.scatter(x2,y2)

# %%
plt.plot(x1,y1,'bo')
plt.plot(x2,y2,'gX')

# %%
x=x1+x2
y=y1+y2

# %%
result1=[1 for i in range(len(x1))]

# %%
result2=[-1 for i in range(len(x2))]

# %%
result=result1+result2

# %%
#result

# %%
z=[]
for i in range(len(x)):
    if result[i]==1:
        z.append(0)
    else:
        z.append(1)

# %%
#z

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(x, y, z,  cmap='Greens',depthshade=False)

# %%
zcutoff=0.5 #could find thru=ough a loop

# %%
zcut=[zcutoff for i in range(len(x))]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(x, y, z,  cmap='Greens',depthshade=False)
ax.plot_trisurf(x, y, zcut, linewidth=0.1, antialiased=True,alpha=0.5)

# %%
#below blocks are just for trying to use plot_surface ignore all of it

# %%
xx=np.arange(np.min(x),np.max(x))
xx=np.arange(np.min(y),np.max(y),0.5)
X=Y=np.array(np.meshgrid(xx,yy))
zs = np.array([0.5 for x,y in zip(np.ravel(X), np.ravel(Y))])
Z = zs.reshape(X.shape)
zz=[0.5 for i in range(len(xx))]

# %%
xx
# Out:
# array([ 5. ,  5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. ,
#        10.5, 11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5,
#        16. , 16.5, 17. , 17.5, 18. , 18.5, 19. , 19.5, 20. , 20.5, 21. ,
#        21.5, 22. , 22.5, 23. , 23.5, 24. , 24.5, 25. , 25.5, 26. , 26.5,
#        27. , 27.5, 28. , 28.5, 29. , 29.5, 30. , 30.5, 31. , 31.5, 32. ,
#        32.5, 33. , 33.5, 34. , 34.5, 35. , 35.5, 36. , 36.5, 37. , 37.5,
#        38. , 38.5, 39. , 39.5])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(x, y, z,  cmap='Greens',depthshade=False)
#ax.plot_trisurf(x, y, zcut, linewidth=0.1, antialiased=True,)
ax.plot_surface(X, Y, Z,cstride=1,color='b')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-dddeedef2e77> in <module>()
#       3 ax.scatter3D(x, y, z,  cmap='Greens',depthshade=False)
#       4 #ax.plot_trisurf(x, y, zcut, linewidth=0.1, antialiased=True,)
# ----> 5 ax.plot_surface(X, Y, Z,cstride=1,color='b')
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1634
#    1635         if Z.ndim != 2:
# -> 1636             raise ValueError("Argument Z must be 2-dimensional.")
#    1637         # TODO: Support masked arrays
#    1638         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.
