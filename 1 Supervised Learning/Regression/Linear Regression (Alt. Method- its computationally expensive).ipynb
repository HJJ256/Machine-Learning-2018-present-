# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
from statistics import mean
from matplotlib import style
style.use('ggplot')
import pandas as pd
from IPython.display import HTML
#%matplotlib notebook

# %%
df = pd.read_csv('Bike Sharing hour.csv')
list(df)
df.drop(['dteday'],1,inplace = True)
df.drop(['instant'],1,inplace = True)
full_data = df.astype(float).values.tolist()

# %%
header = list(df)

# %%
xs = np.array(full_data)[:,:-1]
ys = np.array(full_data)[:,-1]

# %%
x = xs[:,-2]
x
# Out:
# array([ 3.,  8.,  5., ...,  7., 13., 12.])

# %%
plt.scatter(x,ys)

# %%
def origin_shift(x,y):
    return x - np.mean(x) , y-np.mean(y)

# %%
def pred_y(m,x):
    return m*x

# %%
def calc_SSE(y,pred_y):
    return np.linalg.norm(y-pred_y)

# %%
X,Y = origin_shift(x,ys)

# %%
m = 0
y_hat = pred_y(m,X)

# %%
y_hat
calc_SSE(Y,y_hat)
# Out:
# 23911.536777687827

# %%
alpha = 0.1
m = 0
m_list = []
prev_SSE = 99999999
curr_SSE = 0
i = 0
def reg_line(m,X,Y,m_list,prev_SSE,curr_SSE,alpha):
    if(alpha < 0.00001):
        return m , m_list
    y_hat = pred_y(m,X)
    m_list.append(m)
    curr_SSE = calc_SSE(Y,y_hat)
    if(curr_SSE <= prev_SSE):
        prev_SSE = curr_SSE
        m+=alpha
        return reg_line(m,X,Y,m_list,prev_SSE,curr_SSE,alpha)
    else:
        m = m_list[-10]
        for i in range(10):
            m_list.remove(m_list[-1])
        prev_SSE = 999999
        alpha*=0.1
        m+=alpha
        return reg_line(m,X,Y,m_list,prev_SSE,curr_SSE,alpha)

m,m_list = reg_line(m,X,Y,m_list,prev_SSE,curr_SSE,alpha)

# %%
m
c = np.mean(ys)
c
# Out:
# 189.46308763450142

# %%
m_list
# Out:
# [0,
#  0.1,
#  0.2,
#  0.30000000000000004,
#  0.4,
#  0.5,
#  0.6,
#  0.7,
#  0.7999999999999999,
#  0.8999999999999999,
#  0.9999999999999999,
#  1.0999999999999999,
#  1.2,
#  1.3,
#  1.4000000000000001,
#  1.5000000000000002,
#  1.6000000000000003,
#  1.7000000000000004,
#  1.8100000000000005,
#  1.8200000000000005,
#  1.8300000000000005,
#  1.8400000000000005,
#  1.8500000000000005,
#  1.8600000000000005,
#  1.8700000000000006,
#  1.8800000000000006,
#  1.8900000000000006,
#  1.9000000000000006,
#  1.9100000000000006,
#  1.9200000000000006,
#  1.9300000000000006,
#  1.9400000000000006,
#  1.9500000000000006,
#  1.9600000000000006,
#  1.9700000000000006,
#  1.9800000000000006,
#  1.9900000000000007,
#  2.0000000000000004,
#  2.0100000000000002,
#  2.02,
#  2.03,
#  2.0399999999999996,
#  2.0499999999999994,
#  2.059999999999999,
#  2.069999999999999,
#  2.0799999999999987,
#  2.0899999999999985,
#  2.0999999999999983,
#  2.109999999999998,
#  2.119999999999998,
#  2.1299999999999977,
#  2.1399999999999975,
#  2.1499999999999972,
#  2.159999999999997,
#  2.169999999999997,
#  2.1799999999999966,
#  2.1899999999999964,
#  2.199999999999996,
#  2.209999999999996,
#  2.2199999999999958,
#  2.2299999999999955,
#  2.551399999999992,
#  2.5514999999999923,
#  2.5515999999999925,
#  2.5516999999999928,
#  2.551799999999993,
#  2.551899999999993,
#  2.5519999999999934,
#  2.5520999999999936,
#  2.552199999999994,
#  2.552299999999994,
#  2.5523999999999942,
#  2.5524999999999944,
#  2.5525999999999947,
#  2.552699999999995,
#  2.552799999999995,
#  2.5528999999999953,
#  2.5529999999999955,
#  2.5530999999999957,
#  2.553199999999996,
#  2.553299999999996,
#  2.5533999999999963,
#  2.5534999999999966,
#  2.5535999999999968,
#  2.553699999999997,
#  2.553799999999997,
#  2.5538999999999974,
#  2.5539999999999976,
#  2.554099999999998,
#  2.554199999999998,
#  2.5542999999999982,
#  2.5544099999999985,
#  2.5544199999999986,
#  2.5544299999999986,
#  2.5544399999999987,
#  2.5544499999999988,
#  2.554459999999999,
#  2.554469999999999,
#  2.554479999999999,
#  2.554489999999999,
#  2.554499999999999,
#  2.554509999999999,
#  2.5545199999999992,
#  2.5545299999999993,
#  2.5545399999999994,
#  2.5545499999999994,
#  2.5545599999999995,
#  2.5545699999999996,
#  2.5545799999999996,
#  2.5545899999999997,
#  2.5545999999999998,
#  2.55461,
#  2.55462,
#  2.55463,
#  2.55464,
#  2.55465,
#  2.55466,
#  2.55467,
#  2.5546800000000003,
#  2.5546900000000003,
#  2.5547000000000004,
#  2.5547100000000005,
#  2.5547200000000005,
#  2.5547300000000006,
#  2.5547400000000007,
#  2.5547500000000007,
#  2.554760000000001,
#  2.554770000000001,
#  2.554780000000001,
#  2.554790000000001,
#  2.554800000000001,
#  2.554810000000001,
#  2.554820000000001,
#  2.5548300000000013,
#  2.5548400000000013,
#  2.5548500000000014,
#  2.5548600000000015,
#  2.5548700000000015,
#  2.5548800000000016,
#  2.5548900000000017,
#  2.5549000000000017,
#  2.554910000000002,
#  2.554920000000002,
#  2.554930000000002,
#  2.554940000000002,
#  2.554950000000002,
#  2.554960000000002,
#  2.554970000000002,
#  2.5549800000000022,
#  2.5549900000000023,
#  2.5550000000000024,
#  2.5550100000000024,
#  2.5550200000000025,
#  2.5550300000000026,
#  2.5550400000000026,
#  2.5550500000000027,
#  2.5550600000000028,
#  2.555070000000003,
#  2.555080000000003,
#  2.555090000000003,
#  2.555100000000003,
#  2.555110000000003,
#  2.555120000000003,
#  2.5551300000000032]

# %%
plt.scatter(x,ys)
plt.plot(x,m*x+c , color = 'g')

# %%
def reg_line_anim(x,ys,m_list,c):
    fig = plt.figure()
    ax = fig.gca()
    t = []
    t.append(x)
    t.append(c)
    t = tuple(t)
    ax.scatter(x,ys)
    line, = ax.plot(x,(m_list[0]*x)+c,color = 'g')
    def update(m,x,c):
        line.set_data(x,m*x+c)
        return line

    fig.canvas.draw()
    ani = matplotlib.animation.FuncAnimation(fig, update, frames=m_list, blit=False, interval=10, fargs = t )
    return ani #needed in Python Notebooks
    #plt.show() if you are doing in .py file then uncomment this line and comment above line

# %%
ani = reg_line_anim(x,ys,m_list,c)

# %%
HTML(ani.to_html5_video()) #this command is to create animation in notebook
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
